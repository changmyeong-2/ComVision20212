# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

blur = cv2.blur(img,(5,5))
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
kernel = np.ones((5,5), np.float32)/25

dst = cv2.filter2D(img,-1,kernel)

plt.rcParams["figure.figsize"] = (20, 10)

plt.subplot(121), plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(dst),plt.title('Averaging')
plt.xticks([]), plt.yticks([])
# Out:
# (([], []), ([], []))

# %%
blur = cv2.blur(img,(5,5))
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
blur = cv2.GaussianBlur(img,(5,5),0)
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
blur = cv2.bilateralFilter(img,9,75,75)
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('texture.jpg')

kernel = np.ones((5,5), np.float32)/25



blur = cv2.blur(img,(5,5))
bilateralFilter=cv2.bilateralFilter(img,9,75,75)
median = cv2.medianBlur(img,5)
GaussianBlur=cv2.GaussianBlur(img,(5,5),0)

plt.rcParams["figure.figsize"] = (20, 10)
plt.subplot(221),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(222),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.subplot(223,plt.imshow(median),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.subplot(224,plt.imshow(GaussianBlur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()
# Out:
#   File "<ipython-input-14-adf2c57c0c4e>", line 22
#     plt.xticks([]), plt.yticks([])
#     ^
# SyntaxError: invalid syntax

# %%
img = cv2.imread('texture.jpg')
n = 17
kernel = np.ones((n,n),np.float32)/(n*n)

blur = cv2.blur(img,(5,5))
GaussianBlur = cv2.GaussianBlur(img,(5,5),0)
medianBlur = cv2.medianBlur(img,5)
bilateralFilter = cv2.bilateralFilter(img,9,75,75)

plt.rcParams["figure.figsize"] = (20,10)
plt.subplot(221),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(222),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.subplot(223),plt.imshow(GaussianBlur),plt.title('GaussianBlur')
plt.xticks([]), plt.yticks([])
plt.subplot(224),plt.imshow(bilateralFilter),plt.title('bilateralFilter')
plt.xticks([]), plt.yticks([])
plt.show()
