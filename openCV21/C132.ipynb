# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
x = np.uint8([250])

# %%
print(x)
# Out:
# [250]

# %%
y = np.uint8([10])

# %%
print(y)
# Out:
# [10]

# %%
x+y
# Out:
# array([4], dtype=uint8)

# %%
cv2.add(x,y)
# Out:
# array([[255]], dtype=uint8)

# %%
w = 0.5
dst = cv2.addWeighted(img1, w,img2, 1-w, 0)
cv2.imshow('dst',dst)    
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
def nothing(x):
    pass

# %%
cv2.namedWindow('image')
cv2.createTrackbar('weight', 'image', 0, 255, nothing)
while True:
    k = cv2.waitKey(1) & 0xFF 
    if k == 27:
        break
        
    weight = cv2.getTrackbarPos('weight', 'image')
    dst = cv2.addWeighted(img1, weight/255,img2, 1-weight/255, 0)
    cv2.imshow('dst',dst)
    
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Load two images
img1 = cv2.imread('test.png')
img2 = cv2.imread('test2.png')

# I want to put logo on top-left corner, So I create a ROI
rows,cols,channels = img2.shape
roi = img1[0:rows, 0:cols ]

# Now create a mask of logo and create its inverse mask also
img2gray = cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)
ret, mask = cv2.threshold(img2gray, 10, 255, cv2.THRESH_BINARY)
mask_inv = cv2.bitwise_not(mask)

# Now black-out the area of logo in ROI
img1_bg = cv2.bitwise_and(roi,roi,mask = mask_inv)

# Take only region of logo from logo image.
img2_fg = cv2.bitwise_and(img2,img2,mask = mask)

# Put logo in ROI and modify the main image
dst = cv2.add(img1_bg,img2_fg)
img1[0:rows, 0:cols ] = dst

cv2.imshow('res',img1)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img1 = cv2.imread('test3.jpg')
img2 = cv2.imread('test.png')
# I want to put logo on top-left corner, So I create a ROI
rows,cols,channels = img2.shape
roi = img1[0:rows, 0:cols ]
# Now create a mask of logo and create its inverse mask also
img2gray = cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)
ret, mask = cv2.threshold(img2gray, 10, 255, cv2.THRESH_BINARY)
mask_inv = cv2.bitwise_not(mask)
# Now black-out the area of logo in ROI
img1_bg = cv2.bitwise_and(roi,roi,mask = mask_inv)
# Take only region of logo from logo image.
img2_fg = cv2.bitwise_and(img2,img2,mask = mask)
# Put logo in ROI and modify the main image
dst = cv2.add(img1_bg,img2_fg)
img1[0:rows, 0:cols ] = dst
cv2.imshow('res',img1)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img1 = cv2.imread('test3.jpg')
img2 = cv2.imread('test.png')

# %%
def pltImage(img):
    plt.imshow(img)
    plt.xticks([]), plt.yticks([])
    plt.show()

# %%
rows,cols,channels = img2.shape
print(rows,cols,channels)
# Out:
# 580 822 3

# %%
roi = img1[0:rows, 0:cols]

# %%
pltImage(img1)

# %%
pltImage(roi)

# %%
pltImage(img2gray)

# %%
ret, mask = cv2.threshold(img2gray, 10, 255, cv2)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-139-5f670600b02f> in <module>
# ----> 1 ret, mask = cv2.threshold(img2gray, 10, 255, cv2)
#
# error: OpenCV(4.5.3) :-1: error: (-5:Bad argument) in function 'threshold'
# > Overload resolution failed:
# >  - Argument 'type' is required to be an integer
# >  - Argument 'type' is required to be an integer

# %%
img2_fg = cv2.bitwise_and(img2, img2, mask = mask)

# %%
pltImage(img2_fg)

# %%
dst = cv2.add(img1_bg, img2_fg)

# %%
img1[0:rows, 0:cols] = dst

# %%
pltImage(img1)
